# %%
from all_ten import AllTen

# %%
solver = AllTen(
    numbers = [3,5,5,8]
)

solver.get_solutions()
print(solver.solutions)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 6
#       1 solver = AllTen(
#       2     numbers = [3,5,5,8]
#       3 )
#       5 solver.get_solutions()
# ----> 6 print(solver.solutions)
#
# AttributeError: 'AllTen' object has no attribute 'solutions'

# %% [markdown]
# ## Scratch

# %%
def get_concatenations(numbers):
    partitions = []
    for pair in list(itertools.permutations(numbers, 2)):
        remaining = numbers.copy()
        for num in pair:
            remaining.remove(num)
        p = [int(f'{pair[0]}{pair[1]}')] + remaining
        if p not in partitions:
            partitions.append(p)

    print(partitions)
    #
    # return partitions

# %%
get_concatenations(numbers)
# Out:
# [[55, 7, 8], [57, 5, 8], [58, 5, 7], [75, 5, 8], [78, 5, 5], [85, 5, 7], [87, 5, 5]]
